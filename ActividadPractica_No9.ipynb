# %% [markdown]
# <a href="https://colab.research.google.com/github/Juanca25-10/Laboratorios_Collab_Repo/blob/main/ActividadPractica_No9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# JUAN CAMILO LOPEZ SINISTERRA

# %% [markdown]
# Título del Laboratorio: Usando Python con las librerías Pandas, Numpy y Matplot
# Duración: 2 horas
# Objetivos del Laboratorio: Aplicar las habilidades de análisis de datos usando las librerías
# Pandas, NumPy y Matplotlib para resolver problemas simples de negocios y académicos. El
# laboratorio se enfoca en crear DataFrames, realizar cálculos estadísticos, manipular datos y
# visualizarlos gráficamente.
# Materiales Necesarios:
# 1. Google Colab
# Estructura del Laboratorio:
# Actividad 1: Crear un análisis simple de las ventas de un pequeño negocio, incluyendo la
# creación de un DataFrame, el uso de operaciones de NumPy y la visualización de los resultados
# con Matplotlib.
# Los estudiantes trabajarán con los siguientes datos de ventas mensuales:
# Datos de ventas mensuales (en miles)
# data = {“Mes": ["Enero", "Febrero", "Marzo", "Abril", "Mayo", "Junio", "Julio", "Agosto",
# "Septiembre", "Octubre", "Noviembre", "Diciembre"], "Ventas": [25, 30, 28, 35, 40, 50, 55, 60,
# 70, 80, 75, 90],}
# Actividad 2: Realizar un análisis simple de las calificaciones de estudiantes en diferentes
# asignaturas, incluyendo la creación de un DataFrame, el uso de operaciones de NumPy y la
# visualización de los resultados con Matplotlib.
# Los estudiantes trabajarán con los siguientes datos de calificaciones:
# Datos de calificaciones de estudiantes
# data = {"Estudiante": ["Alice", "Bob", "Charlie", "David", "Eva", "Frank", "Grace", "Hannah",
# "Ian", "Jack"], "Matemáticas": [85, 92, 78, 90, 88, 76, 95, 89, 82, 94], "Ciencias": [90, 85, 80,
# 88, 92, 75, 95, 87, 81, 93], "Historia": [78, 82, 88, 90, 85, 80, 92, 84, 79, 91],}
